# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import networkx as nx
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
df = pd.read_csv('Dataset/credit_card_transactions-ibm_v2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24386900 entries, 0 to 24386899
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   User            int64
#  1   Card            int64
#  2   Year            int64
#  3   Month           int64
#  4   Day             int64
#  5   Time            object
#  6   Amount          object
#  7   Use Chip        object
#  8   Merchant Name   int64
#  9   Merchant City   object
#  10  Merchant State  object
#  11  Zip             float64
#  12  MCC             int64
#  13  Errors?         object
#  14  Is Fraud?       object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 2.7+ GB

# %%
for i in df.columns:
    counts = df[i].value_counts()
    
    print(f"Value counts for column {i} : \n {counts}\n")
# Out:
# Value counts for column User :
#  User
# 486     82355
# 396     80749
# 332     70010
# 262     68089
# 1249    65644
#         ...
# 457        25
# 231        21
# 1367       20
# 1767       16
# 1817       15
# Name: count, Length: 2000, dtype: int64
#
# Value counts for column Card :
#  Card
# 0    8696411
# 1    6493597
# 2    4305594
# 3    2790785
# 4    1309120
# 5     563097
# 6     176729
# 7      46383
# 8       5184
# Name: count, dtype: int64
#
# Value counts for column Year :
#  Year
# 2019    1723938
# 2017    1723360
# 2018    1721615
# 2016    1708924
# 2015    1701371
# 2014    1672343
# 2013    1650917
# 2012    1610829
# 2011    1570551
# 2010    1491225
# 2009    1355434
# 2008    1223460
# 2007    1064483
# 2006     908793
# 2005     746653
# 2004     597003
# 2003     466408
# 2002     350732
# 2020     336500
# 2001     257998
# 2000     177729
# 1999     118250
# 1998      78345
# 1997      49753
# 1996      29945
# 1995      20928
# 1994      14316
# 1993       8378
# 1992       5134
# 1991       1585
# Name: count, dtype: int64
#
# Value counts for column Month :
#  Month
# 1     2142220
# 12    2104435
# 10    2075188
# 8     2070407
# 7     2051785
# 11    2026832
# 5     2023412
# 9     2006307
# 3     2002867
# 6     1981230
# 2     1960411
# 4     1941806
# Name: count, dtype: int64
#
# Value counts for column Day :
#  Day
# 21    813404
# 25    813189
# 28    811085
# 1     810649
# 7     810589
# 14    809945
# 18    805571
# 11    805407
# 4     805366
# 15    802795
# 22    801672
# 13    801419
# 24    801404
# 8     800735
# 17    800716
# 20    799693
# 6     799532
# 10    799448
# 27    799244
# 3     799048
# 19    797787
# 16    797447
# 9     797145
# 23    797101
# 5     796347
# 26    796155
# 2     795655
# 12    794908
# 29    729801
# 30    725557
# 31    468086
# Name: count, dtype: int64
#
# Value counts for column Time :
#  Time
# 12:31    30604
# 12:49    30556
# 12:36    30515
# 12:52    30501
# 13:06    30417
#          ...
# 04:15     2735
# 04:25     2725
# 04:08     2717
# 04:14     2716
# 04:03     2696
# Name: count, Length: 1440, dtype: int64
#
# Value counts for column Amount :
#  Amount
# $80.00      250984
# $100.00     242198
# $60.00      193620
# $120.00     152881
# $40.00      106528
#              ...
# $1914.41         1
# $1966.81         1
# $1653.09         1
# $1960.40         1
# $584.63          1
# Name: count, Length: 98953, dtype: int64
#
# Value counts for column Use Chip :
#  Use Chip
# Swipe Transaction     15386082
# Chip Transaction       6287598
# Online Transaction     2713220
# Name: count, dtype: int64
#
# Value counts for column Merchant Name :
#  Merchant Name
#  1799189980464955940    1130230
# -4282466774399734331    1129061
#  2027553650310142703    1028485
# -2088492411650162548     720615
# -1288082279022882052     687779
#                          ...
# -7291739097927076617          1
#  1839782328109824160          1
# -3479094112208305958          1
# -3791948590162093461          1
#  1283531942490434675          1
# Name: count, Length: 100343, dtype: int64
#
# Value counts for column Merchant City :
#  Merchant City
# ONLINE         2720821
# Houston         246036
# Los Angeles     180496
# Miami           178653
# Brooklyn        155425
#                 ...
# Haxtun               1
# Schenevus            1
# Pilot Knob           1
# Accoville            1
# Deer                 1
# Name: count, Length: 13429, dtype: int64
#
# Value counts for column Merchant State :
#  Merchant State
# CA                                  2591830
# TX                                  1793298
# FL                                  1458699
# NY                                  1446864
# OH                                   895970
#                                      ...
# Democratic Republic of the Congo          2
# Tonga                                     2
# Kiribati                                  1
# Paraguay                                  1
# Botswana                                  1
# Name: count, Length: 223, dtype: int64
#
# Value counts for column Zip :
#  Zip
# 98516.0    55679
# 43830.0    48815
# 55024.0    44571
# 95076.0    43656
# 94606.0    43512
#            ...
# 17936.0        1
# 15483.0        1
# 39060.0        1
# 4760.0         1
# 48652.0        1
# Name: count, Length: 27321, dtype: int64
#
# Value counts for column MCC :
#  MCC
# 5411    2860738
# 5499    2680609
# 5541    2638982
# 5812    1797920
# 5912    1407636
#          ...
# 3075        666
# 5722        663
# 4411        634
# 3144        632
# 5733        496
# Name: count, Length: 109, dtype: int64
#
# Value counts for column Errors? :
#  Errors?
# Insufficient Balance                                   242783
# Bad PIN                                                 58918
# Technical Glitch                                        48157
# Bad Card Number                                         13321
# Bad CVV                                                 10740
# Bad Expiration                                          10716
# Bad Zipcode                                              2079
# Bad PIN,Insufficient Balance                              581
# Insufficient Balance,Technical Glitch                     457
# Bad PIN,Technical Glitch                                  128
# Bad Card Number,Insufficient Balance                      122
# Bad CVV,Insufficient Balance                               89
# Bad Expiration,Insufficient Balance                        78
# Bad Card Number,Bad CVV                                    60
# Bad Card Number,Bad Expiration                             54
# Bad Expiration,Bad CVV                                     47
# Bad Expiration,Technical Glitch                            32
# Bad Card Number,Technical Glitch                           25
# Bad CVV,Technical Glitch                                   21
# Bad Zipcode,Insufficient Balance                           13
# Bad Zipcode,Technical Glitch                                7
# Bad Card Number,Bad Expiration,Insufficient Balance         2
# Bad Card Number,Bad Expiration,Technical Glitch             1
# Name: count, dtype: int64
#
# Value counts for column Is Fraud? :
#  Is Fraud?
# No     24357143
# Yes       29757
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# User                     0
# Card                     0
# Year                     0
# Month                    0
# Day                      0
# Time                     0
# Amount                   0
# Use Chip                 0
# Merchant Name            0
# Merchant City            0
# Merchant State     2720821
# Zip                2878135
# MCC                      0
# Errors?           23998469
# Is Fraud?                0
# dtype: int64

# %% [markdown]
# ### Data Preprocessing

# %%
#assuming that each customer has only one credit card
df['Card_id'] = df['User'].astype(str) + "" + df['Card'].astype(str)

# %%
#Clean Amount, remove the currecncy sign and convert the datatype from string to  float
df['Amount'] = df['Amount'].str.replace("$","").astype(float)

# %%
#Convert time to hour and minute because it can't be int

df["Hour"] = df['Time'].str[0:2]
df["Minutes"] = df["Time"].str[3:5]

# %%
#Fill missing errors with no error because no error is recorded 

df["Errors?"] = df["Errors?"].fillna("No error")

# %%
#Drop unwanted columns- Duplicate columns and columns with missing values

df = df.drop(["User","Card","Merchant State","Zip"], axis =1)

# %%
#Convert strings to numeric

df["Is Fraud?"] =df["Is Fraud?"].apply(lambda x:1 if x =='Yes' else 0)

# %%
le = LabelEncoder()
df['Merchant City']=le.fit_transform(df['Merchant City'])
df['Use Chip'] = le.fit_transform(df['Use Chip'])
df['Errors?'] = le.fit_transform(df['Errors?'])

# %%
df['Errors?'].unique()
# Out:
# array([22, 23, 20, 14, 15, 10, 16,  3,  0, 17, 21,  8,  4,  1,  5, 11, 12,
#        13,  7,  2,  9, 18, 19,  6])

# %% [markdown]
# ### Graph Preprocessing for Fraud Detection

# %%
# Create an empty Graph
#We are using multigraph because a user can buy from multiple merchants

G = nx.MultiGraph()

#Add nodes to the graph for each unique card_id, merchant_name
G.add_nodes_from(df['Card_id'].unique(), type="card_id")
G.add_nodes_from(df['Merchant Name'].unique(), type='merchant_name')

# %%
#add edges and properties to edge

for i, row in df.iterrows():
    year = row ["Year"],
    month = row["Month"],
    day = row["Day"],
    hour = row["Hour"],
    minute = row["Minutes"],
    amount = row["Amount"],
    use_chip = row["Use Chip"],
    merchant_city = row["Merchant City"],
    errors = row["Errors?"],
    mcc = row["MCC"]
    G.add_edge(row['Card_id'], row['Merchant Name'], year =year, month = month, day = day, hour=hour, minute = minute, amount=amount, use_chip=use_chip, merchant_city = merchant_city, errors=errors, mcc=mcc)

# %%
#Get the number of number of nodes and edges in the graph

number_nodes = G.number_of_nodes()
number_edges = G.number_of_edges()


print(f"Number of nodes: {number_nodes}")
print(f"Number of edges: {number_edges}")
# Out:
# Number of nodes: 106482
# Number of edges: 24386900

# %%
#convert the graph to an adjancency matrix to see which nodes are connected to each other

adjacent_matrix = nx.adjacency_matrix(G).todense()

# %%
adjacent_matrix.shape
# Out:
# (106482, 106482)

# %%
#To retrieve some sample of nodes in the graph(G) and print their principles

#to get a small sample

sample_nodes = list(G.nodes())[:50]

#To retrieve the properties of the sample nodes
node_properties = nx.get_node_attributes(G, 'type')


#print the properties of the sample nodes
for i in sample_nodes:
    print(f" Node:{i}, properties: {node_properties[i]}")
# Out:
#  Node:00, properties: card_id
#  Node:01, properties: card_id
#  Node:02, properties: card_id
#  Node:03, properties: card_id
#  Node:04, properties: card_id
#  Node:10, properties: card_id
#  Node:11, properties: card_id
#  Node:12, properties: card_id
#  Node:13, properties: card_id
#  Node:14, properties: card_id
#  Node:20, properties: card_id
#  Node:21, properties: card_id
#  Node:22, properties: card_id
#  Node:23, properties: card_id
#  Node:24, properties: card_id
#  Node:30, properties: card_id
#  Node:31, properties: card_id
#  Node:32, properties: card_id
#  Node:33, properties: card_id
#  Node:40, properties: card_id
#  Node:50, properties: card_id
#  Node:51, properties: card_id
#  Node:52, properties: card_id
#  Node:60, properties: card_id
#  Node:61, properties: card_id
#  Node:62, properties: card_id
#  Node:70, properties: card_id
#  Node:80, properties: card_id
#  Node:81, properties: card_id
#  Node:82, properties: card_id
#  Node:83, properties: card_id
#  Node:84, properties: card_id
#  Node:90, properties: card_id
#  Node:100, properties: card_id
#  Node:101, properties: card_id
#  Node:110, properties: card_id
#  Node:120, properties: card_id
#  Node:130, properties: card_id
#  Node:131, properties: card_id
#  Node:132, properties: card_id
#  Node:140, properties: card_id
#  Node:150, properties: card_id
#  Node:151, properties: card_id
#  Node:152, properties: card_id
#  Node:153, properties: card_id
#  Node:154, properties: card_id
#  Node:155, properties: card_id
#  Node:160, properties: card_id
#  Node:161, properties: card_id
#  Node:162, properties: card_id

# %%
ss = 10  # Setting the variable sample size to 10

for j, edge in enumerate(G.edges()):  # Loop through the edges of graph G
    print(G.get_edge_data(*edge))  # Print the data associated with the current edge
    if j >= ss - 1:  # Check if the loop index 'j' is greater than or equal to sample size - 1
        break  # If the condition is met, exit the loop
# Out:
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...
# {0: {'year': (2002,), 'month': (9,), 'day': (1,), 'hour': ('06',), 'minute': ('21',), 'amount': (134.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 1: {'year': (2002,), 'month': (9,), 'day': (10,), 'hour': ('06',), 'minute': ('22',), 'amount': (102.18,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 2: {'year': (2002,), 'month': (9,), 'day': (16,), 'hour': ('06',), 'minute': ('00',), 'amount': (115.34,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 3: {'year': (2002,), 'month': (9,), 'day': (18,), 'hour': ('06',), 'minute': ('19',), 'amount': (128.85,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 4: {'year': (2002,), 'month': (9,), 'day': (23,), 'hour': ('06',), 'minute': ('01',), 'amount': (134.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 5: {'year': (2002,), 'month': (9,), 'day': (24,), 'hour': ('06',), 'minute': ('07',), 'amount': (112.67,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 6: {'year': (2002,), 'month': (9,), 'day': (26,), 'hour': ('06',), 'minute': ('25',), 'amount': (93.37,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 7: {'year': (2002,), 'month': (10,), 'day': (1,), 'hour': ('11',), 'minute': ('34',), 'amount': (34.89,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 8: {'year': (2002,), 'month': (10,), 'day': (4,), 'hour': ('06',), 'minute': ('20',), 'amount': (114.87,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 9: {'year': (2002,), 'month': (10,), 'day': (13,), 'hour': ('06',), 'minute': ('21',), 'amount': (135.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 10: {'year': (2002,), 'month': (10,), 'day': (17,), 'hour': ('06',), 'minute': ('09',), 'amount': (114.05,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 11: {'year': (2002,), 'month': (11,), 'day': (2,), 'hour': ('19',), 'minute': ('59',), 'amount': (12.09,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 12: {'year': (2002,), 'month': (11,), 'day': (3,), 'hour': ('05',), 'minute': ('36',), 'amount': (150.08,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 13: {'year': (2002,), 'month': (11,), 'day': (4,), 'hour': ('06',), 'minute': ('03',), 'amount': (55.61,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 14: {'year': (2002,), 'month': (11,), 'day': (15,), 'hour': ('22',), 'minute': ('06',), 'amount': (186.41,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 15: {'year': (2002,), 'month': (11,), 'day': (19,), 'hour': ('05',), 'minute': ('58',), 'amount': (134.57,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 16: {'year': (2002,), 'month': (11,), 'day': (30,), 'hour': ('16',), 'minute': ('46',), 'amount': (104.81,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 17: {'year': (2002,), 'month': (12,), 'day': (8,), 'hour': ('06',), 'minute': ('22',), 'amount': (113.94,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 18: {'year': (2002,), 'month': (12,), 'day': (10,), 'hour': ('05',), 'minute': ('14',), 'amount': (128.82,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 19: {'year': (2002,), 'month': (12,), 'day': (11,), 'hour': ('06',), 'minute': ('01',), 'amount': (141.19,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 20: {'year': (2002,), 'month': (12,), 'day': (23,), 'hour': ('06',), 'minute': ('23',), 'amount': (117.15,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (22,), 'mcc': 5300}, 21: {'year': (2003,), 'month': (1,), 'day': (2,), 'hour': ('06',), 'minute': ('27',), 'amount': (187.21,), 'use_chip': (2,), 'merchant_city': (6274,), 'errors': (2 ...

# %%
#To retrieve properties of a edges and print

#Retries the properties errors of all the edges
edge_properties = nx.get_edge_attributes(G, 'errors')

#count the number of edges by property value
edge_count_by_property = Counter(edge_properties.values())

#print the count of edges by property value

for property_value, count in edge_count_by_property.items():
    print(f"Property value: {property_value}, Count:{count}")
# Out:
# Property value: (22,), Count:23998469
# Property value: (20,), Count:242783
# Property value: (14,), Count:58918
# Property value: (23,), Count:48157
# Property value: (15,), Count:581
# Property value: (10,), Count:10716
# Property value: (16,), Count:128
# Property value: (3,), Count:13321
# Property value: (0,), Count:10740
# Property value: (21,), Count:457
# Property value: (17,), Count:2079
# Property value: (8,), Count:122
# Property value: (4,), Count:60
# Property value: (1,), Count:89
# Property value: (5,), Count:54
# Property value: (11,), Count:47
# Property value: (12,), Count:78
# Property value: (13,), Count:32
# Property value: (7,), Count:1
# Property value: (2,), Count:21
# Property value: (9,), Count:25
# Property value: (18,), Count:13
# Property value: (19,), Count:7
# Property value: (6,), Count:2

# %%
#prepare the data for input into the model
edge_list = list(G.edges(data=True))

# %%
edge_list
# Out:
# [('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (1,),
#    'hour': ('06',),
#    'minute': ('21',),
#    'amount': (134.09,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (10,),
#    'hour': ('06',),
#    'minute': ('22',),
#    'amount': (102.18,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (16,),
#    'hour': ('06',),
#    'minute': ('00',),
#    'amount': (115.34,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (18,),
#    'hour': ('06',),
#    'minute': ('19',),
#    'amount': (128.85,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (23,),
#    'hour': ('06',),
#    'minute': ('01',),
#    'amount': (134.89,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (24,),
#    'hour': ('06',),
#    'minute': ('07',),
#    'amount': (112.67,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('25',),
#    'amount': (93.37,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (10,),
#    'day': (1,),
#    'hour': ('11',),
#    'minute': ('34',),
#    'amount': (34.89,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (10,),
#    'day': (4,),
#    'hour': ('06',),
#    'minute': ('20',),
#    'amount': (114.87,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (10,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('21',),
#    'amount': (135.41,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (10,),
#    'day': (17,),
#    'hour': ('06',),
#    'minute': ('09',),
#    'amount': (114.05,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (11,),
#    'day': (2,),
#    'hour': ('19',),
#    'minute': ('59',),
#    'amount': (12.09,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (11,),
#    'day': (3,),
#    'hour': ('05',),
#    'minute': ('36',),
#    'amount': (150.08,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (11,),
#    'day': (4,),
#    'hour': ('06',),
#    'minute': ('03',),
#    'amount': (55.61,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (11,),
#    'day': (15,),
#    'hour': ('22',),
#    'minute': ('06',),
#    'amount': (186.41,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (11,),
#    'day': (19,),
#    'hour': ('05',),
#    'minute': ('58',),
#    'amount': (134.57,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (11,),
#    'day': (30,),
#    'hour': ('16',),
#    'minute': ('46',),
#    'amount': (104.81,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (12,),
#    'day': (8,),
#    'hour': ('06',),
#    'minute': ('22',),
#    'amount': (113.94,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (12,),
#    'day': (10,),
#    'hour': ('05',),
#    'minute': ('14',),
#    'amount': (128.82,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (12,),
#    'day': (11,),
#    'hour': ('06',),
#    'minute': ('01',),
#    'amount': (141.19,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2002,),
#    'month': (12,),
#    'day': (23,),
#    'hour': ('06',),
#    'minute': ('23',),
#    'amount': (117.15,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (1,),
#    'day': (2,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (187.21,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (1,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('05',),
#    'amount': (157.23,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (1,),
#    'day': (19,),
#    'hour': ('06',),
#    'minute': ('03',),
#    'amount': (137.22,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (1,),
#    'day': (25,),
#    'hour': ('06',),
#    'minute': ('22',),
#    'amount': (151.82,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (1,),
#    'day': (31,),
#    'hour': ('06',),
#    'minute': ('24',),
#    'amount': (115.48,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (2,),
#    'day': (10,),
#    'hour': ('00',),
#    'minute': ('09',),
#    'amount': (14.68,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (3,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('03',),
#    'amount': (100.21,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (3,),
#    'day': (21,),
#    'hour': ('06',),
#    'minute': ('01',),
#    'amount': (73.88,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (4,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('24',),
#    'amount': (137.14,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (5,),
#    'day': (1,),
#    'hour': ('22',),
#    'minute': ('06',),
#    'amount': (217.77,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (5,),
#    'day': (4,),
#    'hour': ('06',),
#    'minute': ('09',),
#    'amount': (125.65,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (5,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('10',),
#    'amount': (102.22,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (5,),
#    'day': (18,),
#    'hour': ('06',),
#    'minute': ('21',),
#    'amount': (160.81,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (5,),
#    'day': (19,),
#    'hour': ('06',),
#    'minute': ('07',),
#    'amount': (70.23,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (5,),
#    'day': (23,),
#    'hour': ('13',),
#    'minute': ('41',),
#    'amount': (67.53,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (7,),
#    'day': (29,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (114.02,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (8,),
#    'day': (18,),
#    'hour': ('11',),
#    'minute': ('50',),
#    'amount': (32.23,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (10,),
#    'day': (11,),
#    'hour': ('06',),
#    'minute': ('25',),
#    'amount': (162.31,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2003,),
#    'month': (11,),
#    'day': (15,),
#    'hour': ('06',),
#    'minute': ('01',),
#    'amount': (108.08,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2004,),
#    'month': (3,),
#    'day': (23,),
#    'hour': ('06',),
#    'minute': ('16',),
#    'amount': (130.44,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2004,),
#    'month': (5,),
#    'day': (25,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (159.76,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2004,),
#    'month': (8,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('04',),
#    'amount': (91.11,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2004,),
#    'month': (8,),
#    'day': (18,),
#    'hour': ('11',),
#    'minute': ('51',),
#    'amount': (46.16,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2004,),
#    'month': (9,),
#    'day': (27,),
#    'hour': ('06',),
#    'minute': ('23',),
#    'amount': (136.14,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2004,),
#    'month': (11,),
#    'day': (15,),
#    'hour': ('06',),
#    'minute': ('22',),
#    'amount': (156.85,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (1,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('03',),
#    'amount': (124.75,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (1,),
#    'day': (22,),
#    'hour': ('13',),
#    'minute': ('35',),
#    'amount': (57.27,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (2,),
#    'day': (5,),
#    'hour': ('06',),
#    'minute': ('24',),
#    'amount': (117.87,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (3,),
#    'day': (6,),
#    'hour': ('06',),
#    'minute': ('24',),
#    'amount': (127.78,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (3,),
#    'day': (17,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (122.6,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (4,),
#    'day': (6,),
#    'hour': ('06',),
#    'minute': ('17',),
#    'amount': (114.71,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (5,),
#    'day': (29,),
#    'hour': ('11',),
#    'minute': ('39',),
#    'amount': (27.88,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (6,),
#    'day': (4,),
#    'hour': ('06',),
#    'minute': ('14',),
#    'amount': (124.08,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (7,),
#    'day': (14,),
#    'hour': ('13',),
#    'minute': ('31',),
#    'amount': (50.97,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (8,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('03',),
#    'amount': (134.3,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (9,),
#    'day': (23,),
#    'hour': ('06',),
#    'minute': ('25',),
#    'amount': (129.9,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2005,),
#    'month': (12,),
#    'day': (16,),
#    'hour': ('06',),
#    'minute': ('29',),
#    'amount': (136.02,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2006,),
#    'month': (1,),
#    'day': (3,),
#    'hour': ('13',),
#    'minute': ('57',),
#    'amount': (60.4,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2006,),
#    'month': (5,),
#    'day': (29,),
#    'hour': ('06',),
#    'minute': ('44',),
#    'amount': (143.81,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2006,),
#    'month': (6,),
#    'day': (8,),
#    'hour': ('06',),
#    'minute': ('35',),
#    'amount': (74.1,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2006,),
#    'month': (7,),
#    'day': (23,),
#    'hour': ('13',),
#    'minute': ('51',),
#    'amount': (5.47,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2006,),
#    'month': (8,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('12',),
#    'amount': (109.53,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2006,),
#    'month': (10,),
#    'day': (22,),
#    'hour': ('19',),
#    'minute': ('15',),
#    'amount': (15.98,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2006,),
#    'month': (11,),
#    'day': (15,),
#    'hour': ('06',),
#    'minute': ('28',),
#    'amount': (129.82,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2006,),
#    'month': (12,),
#    'day': (15,),
#    'hour': ('13',),
#    'minute': ('33',),
#    'amount': (65.66,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (1,),
#    'day': (28,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (128.41,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (2,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('10',),
#    'amount': (113.85,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (3,),
#    'day': (2,),
#    'hour': ('06',),
#    'minute': ('00',),
#    'amount': (148.5,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (3,),
#    'day': (12,),
#    'hour': ('14',),
#    'minute': ('44',),
#    'amount': (35.74,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (3,),
#    'day': (21,),
#    'hour': ('09',),
#    'minute': ('28',),
#    'amount': (136.26,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (3,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('29',),
#    'amount': (114.8,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (4,),
#    'day': (14,),
#    'hour': ('13',),
#    'minute': ('37',),
#    'amount': (49.79,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (20,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (5,),
#    'day': (2,),
#    'hour': ('06',),
#    'minute': ('09',),
#    'amount': (52.91,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (5,),
#    'day': (20,),
#    'hour': ('12',),
#    'minute': ('50',),
#    'amount': (37.57,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (9,),
#    'day': (14,),
#    'hour': ('13',),
#    'minute': ('40',),
#    'amount': (6.9,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (9,),
#    'day': (27,),
#    'hour': ('12',),
#    'minute': ('56',),
#    'amount': (31.61,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (11,),
#    'day': (25,),
#    'hour': ('05',),
#    'minute': ('58',),
#    'amount': (175.89,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2007,),
#    'month': (12,),
#    'day': (15,),
#    'hour': ('05',),
#    'minute': ('43',),
#    'amount': (136.48,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (3,),
#    'day': (12,),
#    'hour': ('06',),
#    'minute': ('19',),
#    'amount': (119.4,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (20,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (4,),
#    'day': (21,),
#    'hour': ('08',),
#    'minute': ('35',),
#    'amount': (96.72,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (6,),
#    'day': (5,),
#    'hour': ('11',),
#    'minute': ('32',),
#    'amount': (31.9,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (7,),
#    'day': (9,),
#    'hour': ('06',),
#    'minute': ('28',),
#    'amount': (70.34,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (8,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('18',),
#    'amount': (130.25,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (8,),
#    'day': (29,),
#    'hour': ('14',),
#    'minute': ('17',),
#    'amount': (98.41,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (20,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (10,),
#    'day': (14,),
#    'hour': ('07',),
#    'minute': ('09',),
#    'amount': (131.61,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (10,),
#    'day': (20,),
#    'hour': ('06',),
#    'minute': ('00',),
#    'amount': (116.59,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (12,),
#    'day': (18,),
#    'hour': ('10',),
#    'minute': ('52',),
#    'amount': (2.03,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2008,),
#    'month': (12,),
#    'day': (29,),
#    'hour': ('05',),
#    'minute': ('53',),
#    'amount': (125.9,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (2,),
#    'day': (5,),
#    'hour': ('13',),
#    'minute': ('39',),
#    'amount': (60.05,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (3,),
#    'day': (9,),
#    'hour': ('06',),
#    'minute': ('12',),
#    'amount': (128.74,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (4,),
#    'day': (9,),
#    'hour': ('06',),
#    'minute': ('10',),
#    'amount': (161.16,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (5,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('05',),
#    'amount': (78.38,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (7,),
#    'day': (11,),
#    'hour': ('06',),
#    'minute': ('10',),
#    'amount': (109.64,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (7,),
#    'day': (16,),
#    'hour': ('06',),
#    'minute': ('29',),
#    'amount': (147.9,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (8,),
#    'day': (1,),
#    'hour': ('13',),
#    'minute': ('53',),
#    'amount': (7.09,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (8,),
#    'day': (17,),
#    'hour': ('06',),
#    'minute': ('23',),
#    'amount': (126.12,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (8,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('02',),
#    'amount': (140.44,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (9,),
#    'day': (19,),
#    'hour': ('06',),
#    'minute': ('06',),
#    'amount': (153.59,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (11,),
#    'day': (21,),
#    'hour': ('05',),
#    'minute': ('50',),
#    'amount': (121.6,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (20,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2009,),
#    'month': (11,),
#    'day': (21,),
#    'hour': ('05',),
#    'minute': ('58',),
#    'amount': (127.03,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (1,),
#    'day': (3,),
#    'hour': ('11',),
#    'minute': ('58',),
#    'amount': (29.46,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (1,),
#    'day': (14,),
#    'hour': ('06',),
#    'minute': ('18',),
#    'amount': (187.39,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (3,),
#    'day': (2,),
#    'hour': ('06',),
#    'minute': ('07',),
#    'amount': (139.75,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (3,),
#    'day': (5,),
#    'hour': ('06',),
#    'minute': ('00',),
#    'amount': (123.13,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (6,),
#    'day': (18,),
#    'hour': ('13',),
#    'minute': ('48',),
#    'amount': (6.25,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (7,),
#    'day': (29,),
#    'hour': ('11',),
#    'minute': ('38',),
#    'amount': (35.63,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (8,),
#    'day': (25,),
#    'hour': ('06',),
#    'minute': ('25',),
#    'amount': (132.41,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (9,),
#    'day': (23,),
#    'hour': ('06',),
#    'minute': ('05',),
#    'amount': (167.56,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (9,),
#    'day': (28,),
#    'hour': ('00',),
#    'minute': ('28',),
#    'amount': (16.63,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (9,),
#    'day': (28,),
#    'hour': ('14',),
#    'minute': ('08',),
#    'amount': (59.37,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (11,),
#    'day': (8,),
#    'hour': ('05',),
#    'minute': ('26',),
#    'amount': (75.11,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (11,),
#    'day': (8,),
#    'hour': ('06',),
#    'minute': ('12',),
#    'amount': (127.8,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (11,),
#    'day': (20,),
#    'hour': ('16',),
#    'minute': ('43',),
#    'amount': (14.89,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (11,),
#    'day': (21,),
#    'hour': ('06',),
#    'minute': ('19',),
#    'amount': (121.28,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2010,),
#    'month': (12,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('01',),
#    'amount': (214.32,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2011,),
#    'month': (2,),
#    'day': (5,),
#    'hour': ('06',),
#    'minute': ('08',),
#    'amount': (151.83,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2011,),
#    'month': (2,),
#    'day': (12,),
#    'hour': ('06',),
#    'minute': ('20',),
#    'amount': (105.36,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2011,),
#    'month': (4,),
#    'day': (29,),
#    'hour': ('06',),
#    'minute': ('06',),
#    'amount': (106.45,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2011,),
#    'month': (6,),
#    'day': (3,),
#    'hour': ('06',),
#    'minute': ('29',),
#    'amount': (144.08,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2011,),
#    'month': (6,),
#    'day': (6,),
#    'hour': ('06',),
#    'minute': ('29',),
#    'amount': (107.52,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2011,),
#    'month': (8,),
#    'day': (21,),
#    'hour': ('06',),
#    'minute': ('13',),
#    'amount': (125.25,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2011,),
#    'month': (9,),
#    'day': (17,),
#    'hour': ('13',),
#    'minute': ('40',),
#    'amount': (7.46,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2011,),
#    'month': (10,),
#    'day': (15,),
#    'hour': ('09',),
#    'minute': ('16',),
#    'amount': (120.48,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (3,),
#    'day': (5,),
#    'hour': ('06',),
#    'minute': ('26',),
#    'amount': (151.87,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (3,),
#    'day': (26,),
#    'hour': ('16',),
#    'minute': ('23',),
#    'amount': (85.34,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (4,),
#    'day': (22,),
#    'hour': ('06',),
#    'minute': ('24',),
#    'amount': (158.17,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (6,),
#    'day': (5,),
#    'hour': ('06',),
#    'minute': ('21',),
#    'amount': (82.71,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (6,),
#    'day': (9,),
#    'hour': ('06',),
#    'minute': ('24',),
#    'amount': (127.51,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (6,),
#    'day': (12,),
#    'hour': ('06',),
#    'minute': ('26',),
#    'amount': (89.48,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (8,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('05',),
#    'amount': (137.63,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (8,),
#    'day': (18,),
#    'hour': ('06',),
#    'minute': ('19',),
#    'amount': (124.56,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (8,),
#    'day': (29,),
#    'hour': ('06',),
#    'minute': ('13',),
#    'amount': (130.66,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (10,),
#    'day': (6,),
#    'hour': ('06',),
#    'minute': ('29',),
#    'amount': (123.27,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (10,),
#    'day': (17,),
#    'hour': ('05',),
#    'minute': ('47',),
#    'amount': (109.31,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2012,),
#    'month': (11,),
#    'day': (1,),
#    'hour': ('16',),
#    'minute': ('16',),
#    'amount': (11.97,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (1,),
#    'day': (28,),
#    'hour': ('06',),
#    'minute': ('00',),
#    'amount': (127.05,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (2,),
#    'day': (18,),
#    'hour': ('06',),
#    'minute': ('02',),
#    'amount': (166.89,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (3,),
#    'day': (24,),
#    'hour': ('05',),
#    'minute': ('38',),
#    'amount': (127.31,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (3,),
#    'day': (26,),
#    'hour': ('22',),
#    'minute': ('21',),
#    'amount': (152.58,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (3,),
#    'day': (29,),
#    'hour': ('16',),
#    'minute': ('34',),
#    'amount': (13.49,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (4,),
#    'day': (12,),
#    'hour': ('13',),
#    'minute': ('38',),
#    'amount': (60.51,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (4,),
#    'day': (16,),
#    'hour': ('05',),
#    'minute': ('18',),
#    'amount': (143.32,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (5,),
#    'day': (5,),
#    'hour': ('06',),
#    'minute': ('12',),
#    'amount': (130.41,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (6,),
#    'day': (3,),
#    'hour': ('06',),
#    'minute': ('18',),
#    'amount': (94.23,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (6,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('13',),
#    'amount': (112.93,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (11,),
#    'day': (21,),
#    'hour': ('06',),
#    'minute': ('18',),
#    'amount': (122.08,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (20,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2013,),
#    'month': (11,),
#    'day': (23,),
#    'hour': ('06',),
#    'minute': ('04',),
#    'amount': (86.91,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2014,),
#    'month': (2,),
#    'day': (10,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (92.06,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2014,),
#    'month': (4,),
#    'day': (1,),
#    'hour': ('05',),
#    'minute': ('48',),
#    'amount': (120.64,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (20,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2014,),
#    'month': (5,),
#    'day': (9,),
#    'hour': ('06',),
#    'minute': ('01',),
#    'amount': (118.24,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2014,),
#    'month': (7,),
#    'day': (12,),
#    'hour': ('06',),
#    'minute': ('28',),
#    'amount': (127.58,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2014,),
#    'month': (7,),
#    'day': (28,),
#    'hour': ('06',),
#    'minute': ('16',),
#    'amount': (127.62,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2014,),
#    'month': (9,),
#    'day': (4,),
#    'hour': ('06',),
#    'minute': ('07',),
#    'amount': (117.91,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2014,),
#    'month': (9,),
#    'day': (28,),
#    'hour': ('06',),
#    'minute': ('26',),
#    'amount': (150.11,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2014,),
#    'month': (11,),
#    'day': (12,),
#    'hour': ('06',),
#    'minute': ('49',),
#    'amount': (138.3,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2015,),
#    'month': (1,),
#    'day': (21,),
#    'hour': ('06',),
#    'minute': ('06',),
#    'amount': (97.37,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2015,),
#    'month': (2,),
#    'day': (18,),
#    'hour': ('06',),
#    'minute': ('13',),
#    'amount': (122.75,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2015,),
#    'month': (3,),
#    'day': (19,),
#    'hour': ('15',),
#    'minute': ('29',),
#    'amount': (81.7,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2015,),
#    'month': (7,),
#    'day': (29,),
#    'hour': ('13',),
#    'minute': ('38',),
#    'amount': (63.31,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2015,),
#    'month': (10,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('13',),
#    'amount': (72.84,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2015,),
#    'month': (11,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('16',),
#    'amount': (95.46,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2015,),
#    'month': (12,),
#    'day': (8,),
#    'hour': ('06',),
#    'minute': ('25',),
#    'amount': (115.16,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2016,),
#    'month': (1,),
#    'day': (13,),
#    'hour': ('13',),
#    'minute': ('52',),
#    'amount': (56.87,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2016,),
#    'month': (2,),
#    'day': (12,),
#    'hour': ('06',),
#    'minute': ('07',),
#    'amount': (159.14,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2016,),
#    'month': (6,),
#    'day': (29,),
#    'hour': ('14',),
#    'minute': ('28',),
#    'amount': (64.6,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2016,),
#    'month': (8,),
#    'day': (4,),
#    'hour': ('13',),
#    'minute': ('52',),
#    'amount': (75.76,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2016,),
#    'month': (9,),
#    'day': (12,),
#    'hour': ('16',),
#    'minute': ('44',),
#    'amount': (14.02,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2016,),
#    'month': (9,),
#    'day': (20,),
#    'hour': ('06',),
#    'minute': ('46',),
#    'amount': (132.86,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2016,),
#    'month': (10,),
#    'day': (10,),
#    'hour': ('05',),
#    'minute': ('35',),
#    'amount': (62.1,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2016,),
#    'month': (11,),
#    'day': (21,),
#    'hour': ('05',),
#    'minute': ('57',),
#    'amount': (63.11,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2017,),
#    'month': (3,),
#    'day': (2,),
#    'hour': ('06',),
#    'minute': ('21',),
#    'amount': (22.38,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2017,),
#    'month': (5,),
#    'day': (6,),
#    'hour': ('06',),
#    'minute': ('01',),
#    'amount': (118.74,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2017,),
#    'month': (5,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('29',),
#    'amount': (155.88,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2017,),
#    'month': (6,),
#    'day': (18,),
#    'hour': ('06',),
#    'minute': ('56',),
#    'amount': (165.48,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2017,),
#    'month': (10,),
#    'day': (4,),
#    'hour': ('06',),
#    'minute': ('03',),
#    'amount': (157.3,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2017,),
#    'month': (10,),
#    'day': (31,),
#    'hour': ('06',),
#    'minute': ('14',),
#    'amount': (139.59,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2017,),
#    'month': (11,),
#    'day': (14,),
#    'hour': ('06',),
#    'minute': ('17',),
#    'amount': (152.17,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2017,),
#    'month': (12,),
#    'day': (20,),
#    'hour': ('11',),
#    'minute': ('39',),
#    'amount': (34.9,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2018,),
#    'month': (5,),
#    'day': (19,),
#    'hour': ('06',),
#    'minute': ('14',),
#    'amount': (116.27,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (20,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2018,),
#    'month': (9,),
#    'day': (5,),
#    'hour': ('06',),
#    'minute': ('01',),
#    'amount': (139.19,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2018,),
#    'month': (9,),
#    'day': (21,),
#    'hour': ('05',),
#    'minute': ('40',),
#    'amount': (115.58,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2018,),
#    'month': (10,),
#    'day': (11,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (117.34,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2018,),
#    'month': (11,),
#    'day': (30,),
#    'hour': ('16',),
#    'minute': ('39',),
#    'amount': (11.6,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2019,),
#    'month': (5,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('24',),
#    'amount': (123.97,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2019,),
#    'month': (5,),
#    'day': (31,),
#    'hour': ('13',),
#    'minute': ('40',),
#    'amount': (8.64,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2019,),
#    'month': (6,),
#    'day': (2,),
#    'hour': ('06',),
#    'minute': ('18',),
#    'amount': (141.72,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2019,),
#    'month': (9,),
#    'day': (9,),
#    'hour': ('06',),
#    'minute': ('41',),
#    'amount': (132.99,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2019,),
#    'month': (12,),
#    'day': (12,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (101.5,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2019,),
#    'month': (12,),
#    'day': (25,),
#    'hour': ('06',),
#    'minute': ('19',),
#    'amount': (104.39,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   3527213246127876953,
#   {'year': (2020,),
#    'month': (1,),
#    'day': (27,),
#    'hour': ('06',),
#    'minute': ('50',),
#    'amount': (146.1,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5300}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (1,),
#    'hour': ('06',),
#    'minute': ('42',),
#    'amount': (38.48,),
#    'use_chip': (2,),
#    'merchant_city': (7827,),
#    'errors': (22,),
#    'mcc': 5411}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (2,),
#    'hour': ('06',),
#    'minute': ('22',),
#    'amount': (120.34,),
#    'use_chip': (2,),
#    'merchant_city': (7827,),
#    'errors': (22,),
#    'mcc': 5411}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (4,),
#    'hour': ('05',),
#    'minute': ('51',),
#    'amount': (93.84,),
#    'use_chip': (2,),
#    'merchant_city': (7827,),
#    'errors': (22,),
#    'mcc': 5411}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (4,),
#    'hour': ('06',),
#    'minute': ('09',),
#    'amount': (123.5,),
#    'use_chip': (2,),
#    'merchant_city': (7827,),
#    'errors': (22,),
#    'mcc': 5411}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (5,),
#    'hour': ('06',),
#    'minute': ('14',),
#    'amount': (61.72,),
#    'use_chip': (2,),
#    'merchant_city': (7827,),
#    'errors': (22,),
#    'mcc': 5411}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('16',),
#    'amount': (117.05,),
#    'use_chip': (2,),
#    'merchant_city': (7827,),
#    'errors': (22,),
#    'mcc': 5411}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (8,),
#    'hour': ('13',),
#    'minute': ('48',),
#    'amount': (76.57,),
#    'use_chip': (2,),
#    'merchant_city': (7827,),
#    'errors': (22,),
#    'mcc': 5411}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (21,),
#    'hour': ('14',),
#    'minute': ('23',),
#    'amount': (2.79,),
#    'use_chip': (2,),
#    'merchant_city': (7827,),
#    'errors': (22,),
#    'mcc': 5411}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (25,),
#    'hour': ('06',),
#    'minute': ('36',),
#    'amount': (39.38,),
#    'use_chip': (2,),
#    'merchant_city': (7827,),
#    'errors': (22,),
#    'mcc': 5411}),
#  ('00',
#   -727612092139916043,
#   {'year': (2002,),
#    'month': (9,),
#    'day': (27,),
#    'hour': ('06',),
# ...
#    'month': (12,),
#    'day': (18,),
#    'hour': ('06',),
#    'minute': ('42',),
#    'amount': (38.01,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2012,),
#    'month': (12,),
#    'day': (20,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (136.84,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2012,),
#    'month': (12,),
#    'day': (21,),
#    'hour': ('06',),
#    'minute': ('33',),
#    'amount': (40.6,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (2,),
#    'day': (8,),
#    'hour': ('19',),
#    'minute': ('49',),
#    'amount': (15.25,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (2,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('18',),
#    'amount': (141.09,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (4,),
#    'day': (6,),
#    'hour': ('06',),
#    'minute': ('40',),
#    'amount': (140.82,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (4,),
#    'day': (18,),
#    'hour': ('06',),
#    'minute': ('59',),
#    'amount': (42.09,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (4,),
#    'day': (28,),
#    'hour': ('06',),
#    'minute': ('34',),
#    'amount': (39.67,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (5,),
#    'day': (4,),
#    'hour': ('05',),
#    'minute': ('58',),
#    'amount': (78.34,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (6,),
#    'day': (2,),
#    'hour': ('06',),
#    'minute': ('23',),
#    'amount': (157.62,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (6,),
#    'day': (12,),
#    'hour': ('06',),
#    'minute': ('15',),
#    'amount': (170.08,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (6,),
#    'day': (15,),
#    'hour': ('06',),
#    'minute': ('15',),
#    'amount': (91.06,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (6,),
#    'day': (15,),
#    'hour': ('06',),
#    'minute': ('59',),
#    'amount': (46.68,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (6,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('21',),
#    'amount': (119.1,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (7,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('15',),
#    'amount': (120.22,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (8,),
#    'day': (12,),
#    'hour': ('06',),
#    'minute': ('26',),
#    'amount': (125.29,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (8,),
#    'day': (20,),
#    'hour': ('05',),
#    'minute': ('36',),
#    'amount': (116.3,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (8,),
#    'day': (21,),
#    'hour': ('06',),
#    'minute': ('32',),
#    'amount': (47.95,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (9,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('04',),
#    'amount': (128.98,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (10,),
#    'day': (2,),
#    'hour': ('06',),
#    'minute': ('40',),
#    'amount': (47.62,),
#    'use_chip': (2,),
#    'merchant_city': (12790,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (10,),
#    'day': (6,),
#    'hour': ('13',),
#    'minute': ('43',),
#    'amount': (68.9,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (10,),
#    'day': (11,),
#    'hour': ('22',),
#    'minute': ('04',),
#    'amount': (212.29,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (10,),
#    'day': (17,),
#    'hour': ('06',),
#    'minute': ('23',),
#    'amount': (146.15,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (11,),
#    'day': (3,),
#    'hour': ('07',),
#    'minute': ('39',),
#    'amount': (27.98,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (11,),
#    'day': (9,),
#    'hour': ('06',),
#    'minute': ('43',),
#    'amount': (41.89,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2013,),
#    'month': (12,),
#    'day': (22,),
#    'hour': ('06',),
#    'minute': ('40',),
#    'amount': (30.47,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (1,),
#    'day': (16,),
#    'hour': ('14',),
#    'minute': ('07',),
#    'amount': (32.17,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (2,),
#    'day': (8,),
#    'hour': ('06',),
#    'minute': ('34',),
#    'amount': (55.02,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (2,),
#    'day': (23,),
#    'hour': ('06',),
#    'minute': ('27',),
#    'amount': (114.82,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (2,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('28',),
#    'amount': (144.59,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (3,),
#    'day': (28,),
#    'hour': ('06',),
#    'minute': ('17',),
#    'amount': (122.07,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (20,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (3,),
#    'day': (31,),
#    'hour': ('13',),
#    'minute': ('44',),
#    'amount': (44.39,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (4,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('45',),
#    'amount': (37.62,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (4,),
#    'day': (16,),
#    'hour': ('07',),
#    'minute': ('20',),
#    'amount': (155.91,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (5,),
#    'day': (29,),
#    'hour': ('05',),
#    'minute': ('57',),
#    'amount': (93.36,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (20,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (6,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('14',),
#    'amount': (159.21,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (6,),
#    'day': (27,),
#    'hour': ('06',),
#    'minute': ('57',),
#    'amount': (29.81,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (7,),
#    'day': (11,),
#    'hour': ('06',),
#    'minute': ('46',),
#    'amount': (42.71,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (8,),
#    'day': (4,),
#    'hour': ('06',),
#    'minute': ('24',),
#    'amount': (166.07,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (8,),
#    'day': (7,),
#    'hour': ('06',),
#    'minute': ('52',),
#    'amount': (23.09,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (9,),
#    'day': (6,),
#    'hour': ('06',),
#    'minute': ('22',),
#    'amount': (122.5,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (9,),
#    'day': (10,),
#    'hour': ('06',),
#    'minute': ('11',),
#    'amount': (131.27,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (9,),
#    'day': (23,),
#    'hour': ('06',),
#    'minute': ('42',),
#    'amount': (45.35,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (10,),
#    'day': (5,),
#    'hour': ('06',),
#    'minute': ('54',),
#    'amount': (107.45,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (10,),
#    'day': (8,),
#    'hour': ('06',),
#    'minute': ('19',),
#    'amount': (120.5,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (10,),
#    'day': (20,),
#    'hour': ('06',),
#    'minute': ('41',),
#    'amount': (54.45,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (11,),
#    'day': (10,),
#    'hour': ('06',),
#    'minute': ('31',),
#    'amount': (35.13,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (11,),
#    'day': (14,),
#    'hour': ('06',),
#    'minute': ('45',),
#    'amount': (53.31,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (11,),
#    'day': (23,),
#    'hour': ('05',),
#    'minute': ('30',),
#    'amount': (162.66,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (11,),
#    'day': (27,),
#    'hour': ('13',),
#    'minute': ('50',),
#    'amount': (6.77,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2014,),
#    'month': (11,),
#    'day': (28,),
#    'hour': ('06',),
#    'minute': ('21',),
#    'amount': (106.17,),
#    'use_chip': (2,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (1,),
#    'day': (24,),
#    'hour': ('06',),
#    'minute': ('32',),
#    'amount': (35.86,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (1,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('48',),
#    'amount': (38.2,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (2,),
#    'day': (3,),
#    'hour': ('19',),
#    'minute': ('09',),
#    'amount': (14.01,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (2,),
#    'day': (18,),
#    'hour': ('19',),
#    'minute': ('22',),
#    'amount': (14.58,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (3,),
#    'day': (3,),
#    'hour': ('06',),
#    'minute': ('30',),
#    'amount': (38.33,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (3,),
#    'day': (20,),
#    'hour': ('07',),
#    'minute': ('07',),
#    'amount': (40.62,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (3,),
#    'day': (26,),
#    'hour': ('06',),
#    'minute': ('09',),
#    'amount': (147.19,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (4,),
#    'day': (1,),
#    'hour': ('10',),
#    'minute': ('52',),
#    'amount': (2.67,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (4,),
#    'day': (13,),
#    'hour': ('06',),
#    'minute': ('30',),
#    'amount': (48.74,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (5,),
#    'day': (3,),
#    'hour': ('06',),
#    'minute': ('12',),
#    'amount': (182.89,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (5,),
#    'day': (17,),
#    'hour': ('06',),
#    'minute': ('41',),
#    'amount': (43.49,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (5,),
#    'day': (20,),
#    'hour': ('07',),
#    'minute': ('03',),
#    'amount': (33.38,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (5,),
#    'day': (22,),
#    'hour': ('06',),
#    'minute': ('57',),
#    'amount': (22.58,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (6,),
#    'day': (14,),
#    'hour': ('06',),
#    'minute': ('22',),
#    'amount': (129.83,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (6,),
#    'day': (16,),
#    'hour': ('07',),
#    'minute': ('32',),
#    'amount': (31.14,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ('00',
#   5817218446178736267,
#   {'year': (2015,),
#    'month': (6,),
#    'day': (22,),
#    'hour': ('06',),
#    'minute': ('41',),
#    'amount': (27.67,),
#    'use_chip': (0,),
#    'merchant_city': (6274,),
#    'errors': (22,),
#    'mcc': 5912}),
#  ...]

# %%
i = 0
list(edge_list[i][2].values())
# Out:
# [(2002,), (9,), (1,), ('06',), ('21',), (134.09,), (2,), (6274,), (22,), 5300]

# %% [markdown]
# ### Data Splitting

# %%
#prepare the data for input into the model

# Get a list of edges along with their attributes from the graph G
edge_list = list(G.edges(data=True))

# Initialize an empty list to store processed edge attributes
x = []

# Iterate through each edge in the edge_list
for edge in edge_list:
    # Extract values of attributes for the current edge
    edge_values = list(edge[2].values())

    # Process each attribute value in edge_values
    edge_values = [
        float(i[0]) if type(i) == tuple and type(i[0]) == str else i[0] if type(i) == tuple else i 
        for i in edge_values
    ]

    # Append the processed values to the list x
    x.append(edge_values)

# Convert the list x to a PyTorch tensor with dtype float
x = torch.tensor(x, dtype=torch.float)

# %% [markdown]
# ### Pytorch Neural Network - Model Training

# %% [markdown]
# ### simple feedforward neural network

# %% [markdown]
# #### Network X

# %%
class FraudGNN(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(FraudGNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)
    def forward(self,x):
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x.squeeze(-1)

# %%
y = torch.tensor(df['Is Fraud?'].values, dtype=torch.float)
